# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %matplotlib inline

# %%
df = pd.read_csv("data.csv", encoding="latin1")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()

# %%
df.count()

# %%
df.shape

# %%
print("mean")
print(df.mean(numeric_only=True))
print("median")
print(df.mean(numeric_only=True))

# %%
print("\nstandar deviasi")
print(df.std(numeric_only=True))
print("\variance")
print(df.var(numeric_only=True))

# %%
print("\nsMinimum")
print(df.min(numeric_only=True))
print("\nsMaximum")
print(df.max(numeric_only=True))

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.columns

# %%
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='bar', figsize=(12,5), title='Top    10 Produk Terlaris')
plt.tight_layout()
plt.show()

# %%
top_countries = df['Country'].value_counts().head(10)
top_countries.plot(kind='bar', figsize=(12,5), title='Top 10 Negara')
plt.tight_layout()
plt.show()

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['Month'] = df['InvoiceDate'].dt.to_period('M')
df['Revenue'] = df['Quantity'] * df['UnitPrice']
monthly = df.groupby('Month')['Revenue'].sum()
monthly.plot(kind='line', figsize=(12,5), title='Pendapatan per Bulan')
plt.tight_layout()
plt.show()

# %%
df['Revenue'] = df['Quantity'] * df['UnitPrice']

# %%
sns.heatmap(df[['Quantity', 'UnitPrice', 'Revenue', 'CustomerID']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
